# %%
import importlib
importlib.reload(dark_bias)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0bd7dc8d1de0> in <module>
#       1 import importlib
# ----> 2 importlib.reload(dark_bias)
#
# NameError: name 'dark_bias' is not defined

# %%
import sys
import os
pca_path = os.path.abspath("/sdf/home/d/duncanw/repos/lsstcam-bias-stability")
eo_path = os.path.abspath('/sdf/home/d/duncanw/repos/eotest/python/lsst')
if pca_path not in sys.path:
    sys.path.append(pca_path)
if eo_path not in sys.path:
    sys.path.insert(1,eo_path)
import dark_bias

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import astropy.time
from lsst.daf.butler import Butler
import lsst.afw

import lsst.afw.display as afwDisplay

#import lsst.eotest.image_utils as imutils
from pathlib import Path

import sklearn.linear_model
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

import random
from astropy.visualization import (MinMaxInterval, PercentileInterval, SqrtStretch,
                                   ImageNormalize, LogStretch)

import pickle
from astropy.stats import sigma_clip
plt.rcParams['figure.facecolor']='white'
plt.rcParams['axes.formatter.useoffset'] = False
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
from lsst.obs.lsst.cameraTransforms import LsstCameraTransforms
from lsst.obs.lsst.cameraTransforms import ampPixelToCcdPixel

import lsst.afw.cameraGeom as cameraGeom
import lsst.afw.geom as afwGeom

# %%
def mean_serial(this_bias_data):
    return np.mean(this_bias_data['serial_arr'][:,2:], axis=1)
def mean_parallel(this_bias_data):
    return np.mean(this_bias_data['parallel_arr'][2:], axis=0)
def project_principal_components(pca, arr):
    return pca.inverse_transform(pca.transform(arr))
def remove_pca_both(this_bias_data, serial_pca, parallel_pca):
    this_mean_serial = mean_serial(this_bias_data)
    this_mean_parallel = mean_parallel(this_bias_data)
    mean_bias = np.mean(np.concatenate([this_mean_parallel.flat,this_mean_serial.flat]))
    return mean_bias + (this_bias_data['im_arr']-project_principal_components(serial_pca, this_mean_serial.reshape(1, -1)).T) \
-project_principal_components(parallel_pca, this_mean_parallel.reshape(1, -1))

def get_pixel_data(exp, amp):
    
    im = exp.getMaskedImage()[amp.getRawBBox()]
    arr_imaging  = im[amp.getRawDataBBox()].getImage().getArray()
    arr_parallel = im[amp.getRawParallelOverscanBBox()].getImage().getArray()
    arr_serial   = im[amp.getRawHorizontalOverscanBBox()].getImage().getArray()

    metadata = exp.getMetadata()
    
    visit_result = [im, arr_imaging, arr_parallel, arr_serial, metadata]
    visit_result_dict = {}
    datatypes = [('masked_im', object), ('im_arr', object),('parallel_arr', object),('serial_arr', object), ('metadata', object)]
    for i, item in enumerate(visit_result):
            visit_result_dict[datatypes[i][0]] = item
        
    return visit_result_dict

# %%
#runs = ['12672', '12673', '12675', '12677', '12678', '12679']
raft = 'R20'
sensor = 'S21'
repo = '/sdf/group/lsst/camera/IandT/repo_gen3'

# %%
repo_path = "/sdf/group/lsst/camera/IandT/repo_gen3/bot"
#repo_path = "/sdf/group/lsst/camera/IandT/repo_gen3/spot_test/butler.yaml"
butler = Butler(repo_path)

# %%
registry = butler.registry

# %%
for c in registry.queryCollections():
    print(c)
# Out:
# LSSTCam/raw/all
# LSSTCam/calib
# LSSTCam/calib/unbounded
# u/jchiang/bias_12781_test/20210519T193346Z

# %%
collections = 'LSSTCam/raw/all'
#collections = 'u/echarles/calib/bias/run_12781/20210326T180033Z'
subbutler = Butler(repo_path,collections=collections)
subregistry = subbutler.registry

# %%
for dtype in subregistry.queryDatasetTypes():
    try:
        datasetRefs = list(subregistry.queryDatasets(datasetType=dtype,collections=collections))        
        print(len(datasetRefs), dtype )
    except:
        print("Error", dtype )
# Out:
# 2264123 DatasetType('raw', {band, instrument, detector, physical_filter, exposure}, Exposure)
# 0 DatasetType('camera', {instrument}, Camera, isCalibration=True)
# 0 DatasetType('cpBiasProc', {band, instrument, detector, physical_filter, exposure}, Exposure)
# 0 DatasetType('isr_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet)
# 0 DatasetType('bias', {instrument, detector}, ExposureF, isCalibration=True)
# 0 DatasetType('cpBiasCombine_metadata', {instrument, detector}, PropertySet)
# 0 DatasetType('isr_config', {}, Config)
# 0 DatasetType('cpBiasCombine_config', {}, Config)
# 0 DatasetType('packages', {}, Packages)

# %%
dtype = list(subregistry.queryDatasetTypes())[0]

# %%
#i = 0
#for c in subregistry.queryDatasets(datasetType='raw',collections=collections):
#    print(c.dataId)  
#    i += 1
#    if i > 30:
#        break

# %%
detname='R42_S11'

# %%
exposure_list = list(subregistry.queryDimensionRecords("exposure"))

# %%
runs = set()
for expid in exposure_list:
    #expid = registry.expandDataId(expid)
    runs.add(expid.science_program)

# %%
#runs

# %%
dId_large_runs = []
minexps = 50
for run in runs:
    dIds = subbutler.registry.queryDataIds(['exposure', 'detector'] , where=f"exposure.observation_type='bias' AND exposure.science_program='{run}' AND detector.full_name='{detname}'", collections=['LSSTCam/raw/all'])#
    dIds=list(dIds)
    if len(dIds) >= minexps:
        dId_large_runs.append(dIds)

# %%
len(dId_large_runs)
# Out:
# 40

# %%
dIds_12622 = list(subbutler.registry.queryDataIds(['exposure', 'detector'] , where=f"exposure.observation_type='bias' AND exposure.science_program='12622' AND detector.full_name='{detname}'", collections=['LSSTCam/raw/all']))

# %%
#registry.expandDataId(dIds[0]).records.keys()

# %%
#registry.expandDataId(dIds[0]).records['exposure']

# %%
#runnum = registry.expandDataId(dId).records['exposure'].science_program

# %%
dIds[0]
# Out:
# {instrument: 'LSSTCam', detector: 175, exposure: 3019110400135, ...}

# %%
def f(**p):
    if 'par' in p:
        print(p)
f(par='hi')
f(am='ho')
f()
# Out:
# {'par': 'hi'}

# %%
import time

# %%
dId=dIds_12622[8]

# %%
del exp1, exp2
start = time.time()
exp1=subbutler.get('raw', dIds_12622[9])
amp = exp1.getDetector()[0]
print(time.time()-start)
start = time.time()
exp2=subbutler.get('raw', dId, parameters={'amp':amp})
print(time.time()-start)
# Out:
# 0.5990715026855469
# 0.052568912506103516

# %%
det = exp2.getDetector()
amp = det[0]
exp2[amp.getRawDataBBox()]

# %%
def get_exps(dIds, **params):
    nexps = len(dIds)
    exps = []
    try:
        for i, biasid in enumerate(dIds):
            print(f'Getting exp {i+1} of {nexps}', end='\r')
            exp = subbutler.get('raw', biasid, **params)
            exps.append(exp)
        
    except e:
        print('failed to get raw exposure')
        raise e
    print(f'Finished getting {i+1} exps                          ')
    return exps

# %%
import time
start=time.time()
exps= get_exps(dId_large_runs[2][:10], parameters={'amp':amp})
print(time.time()-start)
# Out:
# Finished getting 10 exps
# 1.6222550868988037

# %%
#dIds = dId_large_runs[0]
#runnum = subregistry.expandDataId(dIds[0]).records['exposure'].science_program
#aspic0data, aspic1data = get_run_stats_by_aspic(dId_large_runs[0])
#
#
#aspic_arr_0 = np.array(aspic0data)
#aspic_arr_1 = np.array(aspic1data)

# %%
aspic0data_list = []
aspic1data_list = []

# %%
aspic0data_dic = {}
aspic1data_dic = {}

# %%
def get_aspic_bias_from_cache(dIds, detname, runnum):
    cache_file_prefix = f'aspic_stats/{detname}/{runnum}-{detname}'
    
    try:
        with open(cache_file_prefix + '-aspic0.pickle', 'rb') as f:
            aspic0data = pickle.load(f)
        with open(cache_file_prefix + '-aspic1.pickle', 'rb') as f:
            aspic1data = pickle.load(f)
        aspic0data_dic[runnum] = np.asarray(aspic0data)
        aspic1data_dic[runnum] = np.asarray(aspic1data)
    except EOFError as e:
        print(e)
        raise
    except FileNotFoundError as e:
        print("No cache found")
        raise

# %%
def get_run_stats_by_aspic(dIds, cache_file=None):
    aspic0data = []
    aspic1data = []
    try:
        for biasid in dIds:
            exp = subbutler.get('raw', biasid)
            det = exp.getDetector()
            aspic0_im_data = []
            aspic1_im_data = []
            for amp in det:
                #print(amp.getName())
                
                #exp.getImage().getMaskedImage()[amp.raw]
                visit_result_dict = get_pixel_data(exp, amp)
                result_list = [np.median(visit_result_dict['im_arr']), np.median(visit_result_dict['serial_arr']), np.median(visit_result_dict['parallel_arr'])]
                del visit_result_dict
                
                segname = amp.getName()
                if segname[1] == '0':
                    aspic0_im_data.append(result_list)
                elif segname[1] == '1':
                    aspic1_im_data.append(result_list)
            aspic0data.append(aspic0_im_data)
            aspic1data.append(aspic1_im_data)
            
        if cache_file is not None:
            with open(cache_file + '-aspic0.pickle', 'wb') as f:
                pickle.dump(aspic0data, f)
            with open(cache_file + '-aspic1.pickle', 'wb') as f:
                pickle.dump(aspic1data, f)
    except:
        print('failed to get raw exposure')
    
        
    return aspic0data, aspic1data

# %%
for i, dIds in enumerate(dId_large_runs):
    
    runnum = registry.expandDataId(dIds[0]).records['exposure'].science_program
    print(f'Getting run {runnum}')
    try:
        get_aspic_bias_from_cache(dIds, detname, runnum)
    except:
        pass
# Out:
# Getting run 6779D
# Getting run 6508D
# Getting run 12632
# Getting run 12606
# Getting run 6790D
# Getting run 12761
# Getting run 6514D
# Getting run 6492D
# Getting run 6486D
# Getting run 12729
# Getting run 12672
# Getting run 6813D
# Getting run 12741
# Getting run 6481D
# Getting run 6517D
# Getting run 6545D
# Getting run 6605D
# Getting run 12693
# Getting run 6761D
# Getting run 12629
# Getting run 12639
# Getting run 12635
# Getting run 12549
# Getting run 12692
# Getting run 12781
# Getting run 6488D
# Getting run 6755D
# Getting run 12684
# Getting run 6549D
# Getting run 12631
# Getting run 6547D
# Getting run unknown
#         [23716., 23713., 23716.],
#         [24778., 24777., 24778.]],
#
#        [[26035., 26035., 26035.],
#         [24732., 24731., 24732.],
#         [24014., 24010., 24013.],
#         ...,
#         [23343., 23341., 23343.],
#         [23714., 23712., 23714.],
#         [24779., 24778., 24778.]],
#
#        [[26033., 26034., 26034.],
#         [24732., 24731., 24732.],
#         [24015., 24012., 24015.],
#         ...,
#         [23344., 23342., 23344.],
#         [23716., 23713., 23716.],
#         [24779., 24778., 24779.]],
#
#        ...,
#
#        [[26034., 26035., 26034.],
#         [24732., 24731., 24733.],
#         [24015., 24011., 24015.],
#         ...,
#         [23344., 23342., 23343.],
#         [23714., 23712., 23714.],
#         [24778., 24778., 24778.]],
#
#        [[26034., 26034., 26034.],
#         [24733., 24732., 24732.],
#         [24015., 24011., 24015.],
#         ...,
#         [23345., 23343., 23344.],
#         [23716., 23713., 23716.],
#         [24779., 24779., 24779.]],
#
#        [[26033., 26034., 26033.],
#         [24733., 24731., 24733.],
#         [24015., 24012., 24015.],
#         ...,
#         [23345., 23343., 23346.],
#         [23716., 23713., 23716.],
#         [24779., 24778., 24779.]]], dtype=float32), array([[[26048., 26049., 26049.],
#         [24743., 24742., 24743.],
#         [24009., 24005., 24008.],
#         ...,
#         [23328., 23326., 23329.],
#         [23708., 23705., 23709.],
#         [24775., 24775., 24775.]],
#
#        [[26042., 26043., 26042.],
#         [24738., 24737., 24737.],
#         [24009., 24006., 24010.],
#         ...,
#         [23333., 23331., 23333.],
#         [23709., 23707., 23709.],
#         [24775., 24775., 24776.]],
#
#        [[26045., 26046., 26045.],
#         [24739., 24738., 24740.],
#         [24009., 24006., 24009.],
#         ...,
#         [23331., 23329., 23331.],
#         [23708., 23705., 23708.],
#         [24775., 24775., 24775.]],
#
#        ...,
#
#        [[26049., 26050., 26049.],
#         [24744., 24743., 24745.],
#         [24008., 24005., 24008.],
#         ...,
#         [23327., 23325., 23327.],
#         [23706., 23704., 23706.],
#         [24775., 24775., 24775.]],
#
#        [[26047., 26047., 26047.],
#         [24741., 24740., 24741.],
#         [24009., 24006., 24010.],
#         ...,
#         [23330., 23327., 23330.],
#         [23708., 23705., 23708.],
#         [24774., 24773., 24774.]],
#
#        [[26043., 26044., 26044.],
#         [24739., 24738., 24739.],
#         [24009., 24006., 24009.],
#         ...,
#         [23331., 23329., 23331.],
#         [23707., 23704., 23707.],
#         [24776., 24775., 24776.]]], dtype=float32)])

# %%
try: 
    get_aspic_bias_from_cache(dIds_12622, detname, '12622')
except:
    aspic0data, aspic1data = get_run_stats_by_aspic(dIds_12622, f'aspic_stats/{detname}/12622-{detname}')
    aspic0data_dic['12622'] = np.asarray(aspic0data)
    aspic1data_dic['12622'] = np.asarray(aspic1data)

# %%
for i, dIds in enumerate(dId_large_runs):
    runnum = registry.expandDataId(dIds[0]).records['exposure'].science_program
    if runnnum in aspic0data_dic:
        aspic0data = aspic0data_dic[runnum]
        aspic1data = aspic1data_dic[runnum]
    else:
        try:
            get_aspic_bias_from_cache(dIds, detname, runnum)
        except:
            aspic0data, aspic1data = get_run_stats_by_aspic(dIds, f'aspic_stats/{detname}/{runnum}-{detname}')
            aspic0data_dic[runnum] = aspic0data
            aspic1data_dic[runnum] = aspic1data
        
    if (len(aspic0data)==0) or (len(aspic1data)==0):
        print(f'Skipping run {runnum}')
        continue
        
    aspic_arr_0 = np.asarray(aspic0data)
    aspic_arr_1 = np.asarray(aspic1data)
    
    
    
    fig = plt.figure()
    plt.scatter(np.sum(aspic_arr_0[:,:,1], axis=-1), np.sum(aspic_arr_1[:,:,1], axis=-1))
    plt.title(f'Bias states in {detname}, run {runnum}')
    plt.xlabel('ASPIC 0 bias sum (ADU)')
    plt.ylabel('ASPIC 1 bias sum (ADU)')
    fig.set_facecolor('white')
    plt.gca().ticklabel_format(useOffset=False)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-cf0f8b708d44> in <module>
#       1 for i, dIds in enumerate(dId_large_runs):
#       2     runnum = registry.expandDataId(dIds[0]).records['exposure'].science_program
# ----> 3     if runnnum in aspic0data_dic:
#       4         aspic0data = aspic0data_dic[runnum]
#       5         aspic1data = aspic1data_dic[runnum]
#
# NameError: name 'runnnum' is not defined

# %%
plt.gca().ticklabel_format(useOffset=False)

# %%
for i, dIds in enumerate(dId_large_runs):
    runnum = registry.expandDataId(dIds[0]).records['exposure'].science_program
    if (len(aspic1data_list) > i) and (len(aspic0data_list) > i):
        aspic0data = aspic0data_list[i]
        aspic1data = aspic1data_list[i]
    else:
        print('not here')
        #aspic0data, aspic1data = get_run_stats_by_aspic(dIds)
        #aspic0data_list.append(aspic0data)
        #aspic1data_list.append(aspic1data)
        
    if (len(aspic0data)==0) or (len(aspic1data)==0):
        print(f'Skipping run {runnum}')
        continue
        
    aspic_arr_0 = np.asarray(aspic0data)
    aspic_arr_1 = np.asarray(aspic1data)
    
    
    
    fig = plt.figure()
    plt.scatter(np.median(aspic_arr_0[:,:,1], axis=-1), np.median(aspic_arr_1[:,:,1], axis=-1))
    plt.title(f'Bias states in {detname}, run {runnum}')
    plt.xlabel('ASPIC 0 bias sum (ADU)')
    plt.ylabel('ASPIC 1 bias sum (ADU)')
    fig.set_facecolor('white')
    plt.show()
# Out:
# Skipping run 6549D
# Skipping run 6755D
# Skipping run 6818D
# Skipping run 6790D
# Skipping run 6486D
# Skipping run 12597
# Skipping run 12781
# Skipping run 6481D
# Skipping run 6761D
# Skipping run 6795D
# Skipping run 12761
# Skipping run 6508D
# Skipping run 6517D
# Skipping run 6547D
# Skipping run 6824D
# Skipping run unknown
# Skipping run 6605D
# Skipping run 6492D
# Skipping run 6779D
# Skipping run 6488D
# Skipping run 6813D
# Skipping run 6514D
# Skipping run 6545D

# %%
aspic1data_dic.keys()
# Out:
# dict_keys(['12629', '12636', '12631', '12692', '12741', '12639', '12729', '12606', '12638', '12693', '12632', '12673', '12635', '12672', '12549', '12684', '12622'])

# %%
runnum = '12729'

# %%
aspic_arr_0 = np.asarray(aspic0data_dic[runnum])
aspic_arr_1 = np.asarray(aspic1data_dic[runnum])

# %%
X,Y=np.sum(aspic_arr_0[:,:,1], axis=-1), np.sum(aspic_arr_1[:,:,1], axis=-1)

# %%
colormap = {0:'r', 1:'g', 2:'b'}

# %%
clusters = GaussianMixture(n_components=3, n_init=100)

# %%
#X = np.c_[aspic_arr_0[:,:,1],aspic_arr_1[:,:,1]]

# %%
data = np.c_[X,Y]

# %%
plt.scatter(data[:,0],data[:,1])

# %%
clusters = clusters.fit(data)

# %%
c_labels = clusters.predict(data)
c_colors = [colormap[label] for label in c_labels]

# %%
set(c_labels)
# Out:
# {0, 1, 2}

# %%
original_std = np.std(data,axis=0)
data_clustered = [data[c_labels == label] for label in set(c_labels)]
clustered_std = [np.std(np.asarray(this_cluster), axis=0) for this_cluster in data_clustered]

# %%
print(original_std)
print(clustered_std)
# Out:
# [10.354369  10.0501375]
# [array([1.4000036, 1.3515459], dtype=float32), array([1.8083845, 1.4609692], dtype=float32), array([1.4807796, 3.782272 ], dtype=float32)]

# %%
plt.scatter(X,Y, c=c_colors)

# %%
len(aspic1data_dic.keys())
# Out:
# 16

# %%
minbias0, maxbias0 = np.inf, -np.inf
minbias1, maxbias1 = np.inf, -np.inf

make_plots = False

colormap = {0:'r', 1:'g', 2:'b'}

cluster_labels = {}
if make_plots:
    fig, axes = plt.subplots(4,4, figsize=(23,20))


axes_iter = 0
for runnum in sorted(aspic1data_dic.keys()):
    aspic_arr_0 = np.asarray(aspic0data_dic[runnum])
    aspic_arr_1 = np.asarray(aspic1data_dic[runnum])
    
    X,Y=np.mean(aspic_arr_0[:,:,1], axis=-1), np.mean(aspic_arr_1[:,:,1], axis=-1)
    data = np.c_[X,Y]
    
    minbias0, maxbias0 = min(minbias0, np.min(X)), max(maxbias0, np.max(X))
    minbias1, maxbias1 = min(minbias1, np.min(Y)), max(maxbias1, np.max(Y))
    
    clusters = GaussianMixture(n_components=3, n_init=100)
    clusters = clusters.fit(data)
    c_labels = clusters.predict(data)
    label_sorter = {j:i for i,j in enumerate(np.argsort(clusters.means_[:,1], axis=0)[::-1])}
    sorted_c_labels = [label_sorter[label] for label in c_labels]
    
    cluster_labels[runnum] = sorted_c_labels
    
    #colormap = {j : ['r','g','b'][i] for i,j in enumerate()}
    c_colors = [colormap[label] for label in sorted_c_labels]
    
    original_std = np.std(data,axis=0)
    data_clustered = [data[c_labels == label] for label in set(c_labels)]
    clustered_std = [np.std(np.asarray(this_cluster), axis=0) for this_cluster in data_clustered]
    
    if make_plots:
        ax = axes[axes_iter//4, axes_iter%4]

        ax.get_xaxis().get_major_formatter().set_useOffset(False)
        ax.get_yaxis().get_major_formatter().set_useOffset(False)
        ax.scatter(X,Y, c=c_colors)
        #ax.ticklabel_format(useOffset=True, axis='both')
        ax.set_xlabel('Mean of ASPIC 0 amps (ADU)')
        ax.set_ylabel('Mean of ASPIC 1 amps (ADU)')
        ax.set_title(runnum)
        ax.text(.1,.1, metas[runnum]['SEQFILE'], transform=ax.transAxes)
    axes_iter += 1
   
if make_plots:
    plt.suptitle(f'Clustering of bias exposures by mean per ASPIC of {detname} in several runs\n')
    plt.tight_layout()

    for ax in axes.flat:
        ax.ticklabel_format(useOffset=True, axis='both')
        ax.set_xlim(minbias0-.5, maxbias0+.5)
        ax.set_ylim(minbias1-.5, maxbias1+.5)
        ax.xaxis.get_major_formatter().set_useOffset(True)
        #y_formatter = matplotlib.ticker.ScalarFormatter(useOffset=False)
        #plt.setp(ax.get_xticklabels(), useOffset=True)
        #ax.get_yaxis().get_major_formatter().set_useOffset(True)


    plt.savefig(f'plots/clusters-{detname}.png')
    plt.show()

# %%
runnum='12622'

aspic_arr_0 = np.asarray(aspic0data_dic[runnum])
aspic_arr_1 = np.asarray(aspic1data_dic[runnum])

X,Y=np.mean(aspic_arr_0[:,:,1], axis=-1), np.mean(aspic_arr_1[:,:,1], axis=-1)
data = np.c_[X,Y]
clusters = GaussianMixture(n_components=3, n_init=100)
clusters = clusters.fit(data)
c_labels = clusters.predict(data)
label_sorter = {j:i for i,j in enumerate(np.argsort(clusters.means_[:,1], axis=0)[::-1])}
sorted_c_labels = [label_sorter[label] for label in c_labels]

cluster_labels[runnum] = sorted_c_labels

#colormap = {j : ['r','g','b'][i] for i,j in enumerate()}
c_colors = [colormap[label] for label in sorted_c_labels]

original_std = np.std(data,axis=0)
data_clustered = [data[c_labels == label] for label in set(c_labels)]
clustered_std = [np.std(np.asarray(this_cluster), axis=0) for this_cluster in data_clustered]

if make_plots:

    plt.scatter(X,Y, c=c_colors)
    plt.xlim(minbias0, maxbias0)
    plt.ylim(minbias1, maxbias1)


    plt.text(.1,.1, metas[runnum]['SEQFILE'], transform=plt.gca().transAxes)
    plt.title(f'Clustering of bias exposures by mean per ASPIC of {detname} in 12622\n')
    plt.savefig(f'plots/clusters-{detname}-12622.png')

# %%
sorted(aspic1data_dic.keys())
# Out:
# ['12549',
#  '12606',
#  '12622',
#  '12629',
#  '12631',
#  '12632',
#  '12635',
#  '12636',
#  '12638',
#  '12639',
#  '12672',
#  '12673',
#  '12684',
#  '12692',
#  '12693',
#  '12729',
#  '12741']

# %%
print(list(registry.expandDataId(dId).records))
print(registry.expandDataId(dId).records['exposure'])
# Out:
# [DatabaseDimension(band), GovernorDimension(instrument), DatabaseDimension(detector), DatabaseDimension(physical_filter), DatabaseDimension(exposure)]
# exposure:
#   instrument: 'LSSTCam'
#   id: 3020090600358
#   physical_filter: 'SDSSi'
#   obs_id: 'MC_C_20200906_000358'
#   exposure_time: 0.0
#   dark_time: 0.0208895
#   observation_type: 'bias'
#   observation_reason: 'flat'
#   day_obs: 20200906
#   seq_num: 358
#   group_name: '3020090600358'
#   group_id: 3020090600358
#   target_name: 'UNKNOWN'
#   science_program: '12549'
#   tracking_ra: None
#   tracking_dec: None
#   sky_angle: None
#   zenith_angle: None
#   timespan: Timespan(begin=astropy.time.Time('2020-09-06 15:51:51.593020', scale='tai', format='iso'), end=astropy.time.Time('2020-09-06 15:51:51.593020', scale='tai', format='iso'))

# %%
metas = {}
for run in sorted(aspic1data_dic.keys()):
    dIds = subbutler.registry.queryDataIds(['exposure', 'detector'] , where=f"exposure.observation_type='bias' AND exposure.science_program='{run}' AND detector.full_name='{detname}'", collections=['LSSTCam/raw/all'])#
    dIds=list(dIds)
    dId= dIds[0]
    exp = subbutler.get('raw', dId)
    meta = exp.getMetadata()
    metas[run] = meta

# %%
run = runnum
dIds = subbutler.registry.queryDataIds(['exposure', 'detector'] , where=f"exposure.observation_type='bias' AND exposure.science_program='{run}' AND detector.full_name='{detname}'", collections=['LSSTCam/raw/all'])#
dIds=list(dIds)
dId= dIds[0]
exp = subbutler.get('raw', dId)
meta = exp.getMetadata()
metas[run] = meta

# %%
for run in sorted(aspic1data_dic.keys()):
    print(metas[run]['SEQFILE'])
# Out:
# FP_ITL_2s_ir2_v20.seq
# FP_ITL_2s_ir2_v22.seq
# FP_ITL_2s_ir2_v22_FC_05_SF.seq
# FP_ITL_2s_ir2_v22_FC_10_SF.seq
# FP_ITL_2s_ir2_v22_FC_05_IN_0000.seq
# FP_ITL_2s_ir2_v22_FC_05_IN_0100.seq
# FP_ITL_2s_ir2_v22_FC_05_IN_0600.seq
# FP_ITL_2s_ir2_v22_FC_05_IN_1500.seq
# FP_ITL_2s_ir2_v22_FC_05_IN_3000.seq
# FP_ITL_2s_ir2_v23.seq
# FP_ITL_2s_ir2_v23.seq
# FP_ITL_2s_ir2_v23_ReverseInvert.seq
# FP_ITL_2s_ir2_v23.seq
# FP_ITL_2s_ir2_v23.seq
# FP_ITL_2s_ir2_v24.seq
# FP_ITL_2s_ir2_v23_FF02.seq

# %%
minbias0, maxbias0 = np.inf, -np.inf
minbias1, maxbias1 = np.inf, -np.inf

colormap = {0:'r', 1:'g', 2:'b'}

cluster_labels = {}
fig, axes = plt.subplots(4,4, figsize=(23,20))
axes_iter = 0
for runnum in sorted(list(aspic1data_dic.keys()))[:16]:
    aspic_arr_0 = np.asarray(aspic0data_dic[runnum])
    aspic_arr_1 = np.asarray(aspic1data_dic[runnum])
    
    X,Y=np.mean(aspic_arr_0[:,:,0], axis=-1), np.mean(aspic_arr_1[:,:,0], axis=-1)
    data = np.c_[X,Y]
    
    minbias0, maxbias0 = min(minbias0, np.min(X)), max(maxbias0, np.max(X))
    minbias1, maxbias1 = min(minbias1, np.min(Y)), max(maxbias1, np.max(Y))
    
    clusters = GaussianMixture(n_components=3, n_init=100)
    clusters = clusters.fit(data)
    c_labels = clusters.predict(data)
    label_sorter = {j:i for i,j in enumerate(np.argsort(clusters.means_[:,1], axis=0)[::-1])}
    sorted_c_labels = [label_sorter[label] for label in c_labels]
    
    cluster_labels[runnum] = sorted_c_labels
    
    #colormap = {j : ['r','g','b'][i] for i,j in enumerate()}
    c_colors = [colormap[label] for label in sorted_c_labels]
    
    original_std = np.std(data,axis=0)
    data_clustered = [data[c_labels == label] for label in set(c_labels)]
    clustered_std = [np.std(np.asarray(this_cluster), axis=0) for this_cluster in data_clustered]
    axes[axes_iter//4, axes_iter%4].scatter(X,Y, c=c_colors)
    #axes[axes_iter//4, axes_iter%4].ticklabel_format(useOffset=True, axis='both')
    axes[axes_iter//4, axes_iter%4].set_xlabel('Mean of ASPIC 0 amps (ADU)')
    axes[axes_iter//4, axes_iter%4].set_ylabel('Mean of ASPIC 1 amps (ADU)')
    axes[axes_iter//4, axes_iter%4].set_title(runnum)
    axes_iter += 1
   
plt.suptitle(f'Clustering of bias exposures by mean per ASPIC in several runs\n')
plt.tight_layout()

for ax in axes.flat:
    ax.ticklabel_format(useOffset=True, axis='both')
    ax.set_xlim(minbias0-.5, maxbias0+.5)
    ax.set_ylim(minbias1-.5, maxbias1+.5)
    #ax.get_xaxis().get_major_formatter().set_useOffset(True)
    #ax.get_yaxis().get_major_formatter().set_useOffset(True)

plt.savefig(f'plots/clusters-imaging-{detname}.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-4676a96e6800> in <module>
#      11     aspic_arr_1 = np.asarray(aspic1data_dic[runnum])
#      12
# ---> 13     X,Y=np.mean(aspic_arr_0[:,:,0], axis=-1), np.mean(aspic_arr_1[:,:,0], axis=-1)
#      14     data = np.c_[X,Y]
#      15
#
# IndexError: too many indices for array: array is 1-dimensional, but 3 were indexed

# %%
cmap = {i : ['r','g','b'][j] for i,j in enumerate(np.argsort(clusters.means_[:,0], axis=0)[::-1])}

# %%
clusters.means_
# Out:
# array([[24177.35131344, 23846.42073113],
#        [24177.26238083, 23846.18032607],
#        [24175.        , 23844.96875   ]])

# %%
testmap[0,1,2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-2bdfe73db8aa> in <module>
# ----> 1 testmap[[0,1,2]]
#
# TypeError: unhashable type: 'list'

# %%
dir(clusters)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_check_initial_parameters',
#  '_check_n_features',
#  '_check_parameters',
#  '_compute_lower_bound',
#  '_e_step',
#  '_estimate_log_prob',
#  '_estimate_log_prob_resp',
#  '_estimate_log_weights',
#  '_estimate_weighted_log_prob',
#  '_estimator_type',
#  '_get_param_names',
#  '_get_parameters',
#  '_get_tags',
#  '_initialize',
#  '_initialize_parameters',
#  '_m_step',
#  '_more_tags',
#  '_n_parameters',
#  '_print_verbose_msg_init_beg',
#  '_print_verbose_msg_init_end',
#  '_print_verbose_msg_iter_end',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_set_parameters',
#  '_validate_data',
#  'aic',
#  'bic',
#  'converged_',
#  'covariance_type',
#  'covariances_',
#  'fit',
#  'fit_predict',
#  'get_params',
#  'init_params',
#  'lower_bound_',
#  'max_iter',
#  'means_',
#  'means_init',
#  'n_components',
#  'n_features_in_',
#  'n_init',
#  'n_iter_',
#  'precisions_',
#  'precisions_cholesky_',
#  'precisions_init',
#  'predict',
#  'predict_proba',
#  'random_state',
#  'reg_covar',
#  'sample',
#  'score',
#  'score_samples',
#  'set_params',
#  'tol',
#  'verbose',
#  'verbose_interval',
#  'warm_start',
#  'weights_',
#  'weights_init']

# %%
plt.scatter(np.arange(len(c_labels)), c_labels, linestyle='None', marker='o', color=c_colors)

# %%
axes_iter
# Out:
# 16

# %%
dir(dark_bias)
# Out:
# ['Butler',
#  'ImageNormalize',
#  'LogStretch',
#  'MinMaxInterval',
#  'PCA',
#  'PCA_Corrector',
#  'Path',
#  'PercentileInterval',
#  'SqrtStretch',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__main__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'astropy',
#  'do_PCA_correction',
#  'do_dark_clipping',
#  'get_pixel_data',
#  'get_selected_bias_and_dark_visits',
#  'lsst',
#  'make_superbias_and_dark_from_corrected_clipped',
#  'make_superbias_and_dark_regression',
#  'mean_parallel',
#  'mean_serial',
#  'np',
#  'os',
#  'pd',
#  'pickle',
#  'plot_superbias',
#  'plt',
#  'project_principal_components',
#  'random',
#  'remove_pca_both',
#  'run_dark_regression_analysis_on_a_sensor',
#  'run_dark_regression_analysis_on_all_sensors',
#  'sigma_clip',
#  'sklearn',
#  'sys']

# %%
for dIds in dId_large_runs:
    if registry.expandDataId(dIds[0]).records['exposure'].science_program == runnum:
        
        print(registry.expandDataId(dIds[0]).records['exposure'].science_program)
        break

# %%
dIds
# Out:
# [{instrument: 'LSSTCam', detector: 175, exposure: 3019040200271, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200255, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200274, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200276, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200235, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200222, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200236, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200234, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200226, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200272, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200224, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200267, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200248, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200269, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200220, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200240, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200227, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200245, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200213, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200225, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200253, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200221, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200278, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200210, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200217, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200238, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200251, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200247, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200237, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200228, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200239, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200209, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200246, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200270, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200219, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200252, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200215, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200244, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200208, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200216, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200211, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200264, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200249, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200223, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200250, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200231, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200233, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200232, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200268, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200229, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200266, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200265, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200257, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200207, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200212, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200273, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200214, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200243, ...},
#  {instrument: 'LSSTCam', detector: 175, exposure: 3019040200241, ...}]

# %%
c_labels = cluster_labels[runnum]
dIds_clustered = [[dIds[index] for index in np.where(np.asarray(c_labels) == label)[0]] for label in set(c_labels)]

# %%
dIds_clustered
# Out:
# [[{instrument: 'LSSTCam', detector: 175, exposure: 3020111400191, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400185, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400017, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400192, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400145, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400012, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400124, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400020, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400175, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400142, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400103, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400154, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400181, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400025, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400184, ...}],
#  [{instrument: 'LSSTCam', detector: 175, exposure: 3020111400076, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400019, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400148, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400097, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400133, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400082, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400004, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400139, ...}],
#  [{instrument: 'LSSTCam', detector: 175, exposure: 3020111400187, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400194, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400197, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400169, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400023, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400166, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400001, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400151, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400112, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400073, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400007, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400106, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400002, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400016, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400188, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400189, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400127, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400013, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400200, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400195, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400085, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400160, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400094, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400091, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400021, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400186, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400157, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400018, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400009, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400027, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400183, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400003, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400100, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400130, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400163, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400011, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400088, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400115, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400109, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400199, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400198, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400136, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400014, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400015, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400029, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400193, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400005, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400178, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400118, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400196, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400008, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400172, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400190, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400182, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400079, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400121, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400006, ...},
#   {instrument: 'LSSTCam', detector: 175, exposure: 3020111400010, ...}]]

# %%
det = exp.getDetector()

# %%
lsst.afw.cameraGeom.detector.detector.Detector()

# %%
exps[0][det[3].getRawBBox()]

# %%
runnum
# Out:
# '12741'

# %%
mean_ims = []
std_ims = []

exp = subbutler.get('raw',dIds_clustered[0][0])
det = exp.getDetector()
amp = det[0]
for i, dIds in enumerate(dIds_clustered):
    exps = get_exps(dIds, parameters={'amp':amp})
    det = exps[0].getDetector()
    amp = det[0]
    corrector = dark_bias.PCA_Corrector(exps, amp)
    corrected_arr = dark_bias.do_PCA_correction(exps, corrector)
    fig, axes = plt.subplots(1,2,figsize=(10,15))
    
    mean_im = np.mean(corrected_arr, axis=0)
    mean_ims.append(mean_im)
    std_im = np.std(corrected_arr, axis=0)
    std_ims.append(std_im)
    implot = axes[0].imshow(std_im)
    plt.colorbar(implot, ax=axes[0])
    axes[1].hist(std_im.flat,bins=100, orientation="horizontal")
    plt.suptitle(f'Pixel-wise stdev in {detname} - {amp.getName()} - {runnum} - Cluster {i}')
    plt.tight_layout()
    plt.savefig(f'plots/Pixel-wise stdev in {detname} - {amp.getName()} - {runnum} - Cluster {i}.png')
    plt.show()
    for exp in exps:
        del exp
    del corrected_arr
# Out:
# Finished getting 15 exps
# Finished getting 7 exps
# Finished getting 3 exps

# %%
det = exps[0].getDetector()
amp = det[0]

# %%
corrector = dark_bias.PCA_Corrector(exps, amp)

# %%
corrected_arr = dark_bias.do_PCA_correction(exps, corrector)

# %%
corrected_arr.shape
# Out:
# (15, 2000, 509)

# %%
fig, axes = plt.subplots(1,2,figsize=(10,15))
implot = axes[0].imshow(np.std(corrected_arr, axis=0))
plt.colorbar(implot ax=axes[0])
axes[1].hist(np.std(corrected_arr, axis=0).flat,bins=100, orientation="horizontal")

plt.show()

# %%
fig, axes = plt.subplots(1,2,figsize=(10,15))
implot = axes[0].imshow(np.mean(corrected_arr, axis=0))
plt.colorbar(implot, ax=axes[0])
axes[1].hist(np.mean(corrected_arr, axis=0).flat,bins=1000,orientation="horizontal")

plt.show()

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
import sklearn.svm as svm

#lin_clf = svm.LinearSVR()
#lin_clf.fit(X, Y)
#LinearSVC()
#dec = lin_clf.decision_function([[1]])
#dec.shape[1]

clf = make_pipeline(StandardScaler(), svm.LinearSVC())
clf.fit(np.c_[X,Y])
clf.score(np.c_[X,Y])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-d58b72c95662> in <module>
#      10
#      11 clf = make_pipeline(StandardScaler(), svm.LinearSVC())
# ---> 12 clf.fit(np.c_[X,Y])
#      13 clf.score(np.c_[X,Y])
#
# /opt/lsst/software/stack/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     333             if self._final_estimator != 'passthrough':
#     334                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 335                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     336
#     337         return self
#
# /opt/lsst/software/stack/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/sklearn/svm/_classes.py in fit(self, X, y, sample_weight)
#     227         X, y = self._validate_data(X, y, accept_sparse='csr',
#     228                                    dtype=np.float64, order="C",
# --> 229                                    accept_large_sparse=False)
#     230         check_classification_targets(y)
#     231         self.classes_ = np.unique(y)
#
# ValueError: too many values to unpack (expected 2)

# %%
len(aspic_arr_1)
# Out:
# 544

# %%
dId = registry.expandDataId(dIds[0])
print(dId.records['exposure'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-360b6afac203> in <module>
# ----> 1 dId = registry.expandDataId(dIds[0])
#       2 print(dId.records['exposure'])
#
# IndexError: list index out of range

# %%
dId

# %%
exposure_list = list(registry.queryDimensionRecords("exposure"))

# %%
exposure_list[0].science_program
# Out:
# '6475D'

# %%
runs
# Out:
# {'11973',
#  '11974',
#  '12470',
#  '12471',
#  '12472',
#  '12473',
#  '12474',
#  '12475',
#  '12476',
#  '12477',
#  '12478',
#  '12479',
#  '12481',
#  '12482',
#  '12483',
#  '12484',
#  '12485',
#  '12486',
#  '12487',
#  '12488',
#  '12489',
#  '12490',
#  '12491',
#  '12492',
#  '12493',
#  '12504',
#  '12505',
#  '12506',
#  '12507',
#  '12508',
#  '12509',
#  '12510',
#  '12511',
#  '12512',
#  '12513',
#  '12522',
#  '12549',
#  '12550',
#  '12584',
#  '12585',
#  '12586',
#  '12587',
#  '12588',
#  '12589',
#  '12590',
#  '12591',
#  '12592',
#  '12593',
#  '12594',
#  '12595',
#  '12596',
#  '12597',
#        [  7.39169472,  -3.1266933 ],
#        [  7.64306311, -10.02356892],
#        [  8.68185687,  -4.53683537],
#        [  5.37042238,  -2.44715237],
#        [  9.24223825,  -3.88003098],
#        [  5.73005848,  -4.19481136],
#        [  7.9683312 ,  -3.23125265],
#        [  7.37578372,  -8.7241701 ],
#        [  6.95292352,  -8.22624269],
#        [  8.21201164,  -1.54781358],
#        [  6.85086785,  -9.92422452],
#        [  5.64443032,  -8.21045789],
#        [ 10.48848359,  -2.75858164],
#        [  7.27059007,  -4.84225716],
#        [  6.29784608, -10.53468031],
#        [  9.42169269,  -2.6476988 ],
#        [  8.98426675,  -4.87449712],
#        [  6.6008728 ,  -8.07144707],
#        [  5.95313618,  -6.82945967],
#        [  6.87151089, -10.18071547],
#        [  6.26221548,  -8.43925752],
#        [  7.97164446,  -3.38236058],
#        [  7.67619643,  -2.82620437],
#        [  7.92736799,  -9.7615272 ],
#        [  5.86311158, -10.19958738],
#        [  8.07502382,  -4.25949569],
#        [  6.78335342,  -8.09238614],
#        [  7.89359985,  -7.41655113],
#        [  6.04907774,  -8.76969991],
#        [  6.77811308,  -9.80940478],
#        [  8.71445065,  -2.41730491],
#        [  8.49142837,  -2.54974889],
#        [  9.49649411,  -3.7902975 ],
#        [  7.52132141,  -2.12266605],
#        [  6.3883927 ,  -9.25691447],
#        [  7.93333064,  -3.51553205],
#        [  6.86866543, -10.02289012]])

# %%
registry.dimensions(datalist[10000].dataId)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-17a8ab026f99> in <module>
# ----> 1 registry.dimensions(datalist[10000].dataId)
#
# TypeError: 'DimensionUniverse' object is not callable

# %%
exposure_list[0].day_obs
# Out:
# 20190319

# %%
for item in c.dataId.values():
    print(item)

# %%
dtype = 'raw'#DatasetType('raw', {band, instrument, detector, physical_filter, exposure}, Exposure)
datasets = subregistry.queryDatasets(datasetType=dtype,collections=collections)
#for dataset in datasets:
#    print(dataset)

# %%
datalist = list(datasets)

# %%
datalist[0].expanded(datalist[0].dataId)
# Out:
# DatasetRef(DatasetType('raw', {band, instrument, detector, physical_filter, exposure}, Exposure), {band: unknown, instrument: LSSTCam, detector: 116, physical_filter: unknown, exposure: 3020110700207}, id=1, run='LSSTCam/raw/all')

# %%
exp = subbutler.get(datalist[0])
afwDisplay.setDefaultBackend('matplotlib') 
fig = plt.figure(figsize=(10,10))
afw_display = afwDisplay.Display(1)
afw_display.scale('asinh', 'zscale')
afw_display.mtv(exp.getImage())
# Out:
# raw@{band: unknown, instrument: LSSTCam, detector: 116, physical_filter: unknown, exposure: 3020110700207}, sc=Exposure] (id=1)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-57-69cb0e91f2cb> in <module>
#       1 print(datalist[0])
# ----> 2 exp = subbutler.get(datalist[0])
#       3 afwDisplay.setDefaultBackend('matplotlib')
#       4 fig = plt.figure(figsize=(10,10))
#       5 afw_display = afwDisplay.Display(1)
#
# /opt/lsst/software/stack/stack/miniconda3-py37_4.8.2-cb4e2dc/Linux64/daf_butler/21.0.0+187b78b4b8/python/lsst/daf/butler/_butler.py in get(self, datasetRefOrType, dataId, parameters, collections, **kwds)
#     886         log.debug("Butler get: %s, dataId=%s, parameters=%s", datasetRefOrType, dataId, parameters)
#     887         ref = self._findDatasetRef(datasetRefOrType, dataId, collections=collections, **kwds)
# --> 888         return self.getDirect(ref, parameters=parameters)
#     889
#     890     def getURIs(self, datasetRefOrType: Union[DatasetRef, DatasetType, str],
#
# /opt/lsst/software/stack/stack/miniconda3-py37_4.8.2-cb4e2dc/Linux64/daf_butler/21.0.0+187b78b4b8/python/lsst/daf/butler/_butler.py in getDirect(self, ref, parameters)
#     753             The dataset.
#     754         """
# --> 755         return self.datastore.get(ref, parameters=parameters)
#     756
#     757     def getDirectDeferred(self, ref: DatasetRef, *,
#
# /opt/lsst/software/stack/stack/miniconda3-py37_4.8.2-cb4e2dc/Linux64/daf_butler/21.0.0+187b78b4b8/python/lsst/daf/butler/datastores/fileDatastore.py in get(self, ref, parameters)
#    1135             Formatter failed to process the dataset.
#    1136         """
# -> 1137         allGetInfo = self._prepare_for_get(ref, parameters)
#    1138         refComponent = ref.datasetType.component()
#    1139
#
# /opt/lsst/software/stack/stack/miniconda3-py37_4.8.2-cb4e2dc/Linux64/daf_butler/21.0.0+187b78b4b8/python/lsst/daf/butler/datastores/fileDatastore.py in _prepare_for_get(self, ref, parameters)
#     467         fileLocations = self._get_dataset_locations_info(ref)
#     468         if not fileLocations:
# --> 469             raise FileNotFoundError(f"Could not retrieve dataset {ref}.")
#     470
#     471         # The storage class we want to use eventually
#
# FileNotFoundError: Could not retrieve dataset raw@{band: unknown, instrument: LSSTCam, detector: 116, physical_filter: unknown, exposure: 3020110700207}, sc=Exposure] (id=1).

# %%
biases = subregistry.queryDatasets('raw', ['visit'], 
                                    dataId={'run':'7004D', 'imageType' : 'BIAS','raftName': raft,'detectorName': sensor})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-57182a2012f7> in <module>
#       1 biases = subregistry.queryDatasets('raw', ['visit'],
# ----> 2                                     dataId={'run':'7004D', 'imageType' : 'BIAS','raftName': raft,'detectorName': sensor})
#
# TypeError: queryDatasets() takes 2 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given

# %%
biases = subregistry.queryDimensions('raw', ['visit'], 
                                    dataId={'run':'7004D', 'imageType' : 'BIAS','raftName': raft,'detectorName': sensor})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-958e5fa12ff2> in <module>
# ----> 1 biases = subregistry.queryDimensions('raw', ['visit'],
#       2                                     dataId={'run':'7004D', 'imageType' : 'BIAS','raftName': raft,'detectorName': sensor})
#
# AttributeError: 'Registry' object has no attribute 'queryDimensions'

# %%
exp = subbutler.get(c.dataId)

# %%
dir(subbutler)
# Out:
# ['GENERATION',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_config',
#  '_findDatasetRef',
#  '_standardizeArgs',
#  '_unpickle',
#  'collections',
#  'datasetExists',
#  'datastore',
#  'export',
#  'get',
#  'getDeferred',
#  'getDirect',
#  'getDirectDeferred',
#  'getURI',
#  'getURIs',
#  'import_',
#  'ingest',
#  'isWriteable',
#  'makeRepo',
#  'pruneCollection',
#  'pruneDatasets',
#  'put',
#  'registry',
#  'run',
#  'storageClasses',
#  'tags',
#  'transaction',
#  'validateConfiguration']
